# %% [markdown]
# ### 함수
# - 자주 사용하는 한 부분
# - 입력 -> (결과)출력
# '''
# # 함수 구조 :
# def 함수명(매개변수1, 매개변수2...):
#     해야할 일들
#     해야할 일들
#     return 실행 후 결과값.....

# %%
# "+"   반복적으로 기능을 재사용하고 싶으면 함수로 만든다.
a=3
b=4
a+b

# %%
def add(a, b):
    return a+b

# %%
print(add(3,4))
print(add(8,9))
print(add(15,30))
